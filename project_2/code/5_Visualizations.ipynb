# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
pd.set_option('display.float_format', str)

# %%
table = pd.DataFrame({'Model':['Underfit', 'Overfit', 'reduced onehot', 'reduced numeric', 'reduced 1hot ridgeCV (Best)', 'reduced 1hot lassoCV (Best)', 'reduced numeric ridgeCV(best)', 'reduced numeric lassoCV(best)'],'# Features' :[39,263, 147, 44, 147, 147, 44, 44 ], 'R2 Training Data': [0.8274203264852614,0.9480446618012022,  0.9480446618012022, 0.9212572911121156, 0.85320553187025, 0.9209226427975585, 0.853115423925284, 0.8056179127104846], 'R2 Test Data':[0.8574404716022525, 0.7756839765035066, 0.7849465219114472,0.7894898250668314, 0.7653648236174785, 0.8084733158525769, 0.7759227396051694,0.8583320324631964], 'Mean Squared Error Train':[1047828067.7968353, 302902197.7328259, 504518913.2209439,859289303.1545429, 506663066.0746632, 602339984.5117174, 860149118.5720009, 1043420588.3012797],'Mean Squared Error Test':[894017622.2843026, 1709187344.2759871, 1267222410.866267,1714364272.709657, 1240450578.9059782, 1128588612.4128618, 1586310994.7344778, 1015110760.7379383]})

# %%
table_new = pd.read_pickle('../datasets/pickles/table.pkl')

# %%
sns.regplot(data = table_new, x='# Features', y = 'Root Mean Squared Error Train')
# Out:
# <AxesSubplot:xlabel='# Features', ylabel='Root Mean Squared Error Train'>

# %%
table_new = pd.read_pickle('../datasets/pickles/table.pkl')

# %%
sns.regplot(data = table_new, x='# Features', y = 'Root Mean Squared Error Test')
# Out:
# <AxesSubplot:xlabel='# Features', ylabel='Root Mean Squared Error Test'>
